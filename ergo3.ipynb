# %%
import numpy as np
import seaborn as sb
import port as pt
import grader as gd
import data_translation as dt

# %%
data = pt.DataHandler('dialogues.tsv')

# %%
labels = [['й', 'ц', 'у', 'к', 'е', 'н', 'г', 'ш', 'щ', 'з', 'х', 'ъ'], 
                ['ф', 'ы', 'в', 'а', 'п', 'р', 'о', 'л', 'д', 'ж', 'э', ''],
                ['я', 'ч', 'с', 'м', 'и', 'т', 'ь', 'б', 'ю', '', '', '']]

# %%
grades = gd.NiterateAlgo(labels, data.DfToNp, 5)

# %%
dt.drawLayout(grades[-10][0], dt.translationMatcher, 0, data.generateDframe())

# %%
gd.NcalcResults(grades[-10][0], data.DfToNp)
# Out:
# [0.13678570864136008,
#  0.2833363857115233,
#  0.05544784430825983,
#  0.6010573469038659,
#  0.02413648685834982]

# %%
gd.NcalcResults(grades[-1][0], data.DfToNp)
# Out:
# [0.10994313744812506,
#  0.3369112008954469,
#  0.07875298420324563,
#  0.73175452557676,
#  0.05193303856966488]

# %%
gd.NcalcResults(labels, data.DfToNp)
# Out:
# [0.39177982157997293,
#  0.4793257931844888,
#  0.2225897213256184,
#  0.6693012409079415,
#  0.08799146387719585]

# %%
dyctL = [['ц','ь','я','','','з','в','к','д','ч','ш','щ'],
         ['у','и','е','о','а','л','н','т','с','р','й',''],
         ['ф','э','х','ы','ю','б','м','п','г','ж','','']]

# %%
gd.NcalcResults(dyctL, data.DfToNp)
# Out:
# [0.21496819638846332,
#  0.1858603151169882,
#  0.04077063097770307,
#  0.48337282831813655,
#  0.006831594252480328]

# %%
len(data.phrases)
# Out:
# 318851
